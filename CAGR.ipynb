# %%
import yfinance as yf

# %%
tickers = ["AMZN", "GOOG", "MSFT"]
ohlcv_data={}

# %%
for ticker in tickers:
    temp = yf.download(ticker, period='1y', interval='1d')
    temp.dropna(how='any', inplace=True)
    ohlcv_data[ticker] = temp
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def CAGR(DF):
    df = DF.copy()
    df["return"] = df["Close"].pct_change()
    df["cum_return"] = (1+df["return"]).cumprod()
    n = len(df)/252
    CAGR = (df["cum_return"].iloc[-1])**(1/n) - 1
    return CAGR * 100

# %%
for ticker in ohlcv_data:
    print("CAGR for {} = {}".format(ticker, CAGR(ohlcv_data[ticker])))
# Out:
# CAGR for AMZN = 10.764691048377362
# CAGR for GOOG = 87.58069572640717
# CAGR for MSFT = -22.687631988352997
