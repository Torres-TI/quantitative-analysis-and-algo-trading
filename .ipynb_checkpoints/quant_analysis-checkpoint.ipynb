# %%
import datetime as dt
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
stocks = ["AMZN", "MSFT", "META", "GOOG", "TSLA", "AAPL", "NVDA"]
start = dt.datetime.today() - dt.timedelta(3650)
end = dt.datetime.today()
cl_price = pd.DataFrame()
ohlcv_data = {}

# %%
for ticker in stocks:
    cl_price[ticker] = yf.download(ticker,start,end)["Close"]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
cl_price.dropna(axis=0, inplace=True)

# %%
cl_price
# Out:
#                   AMZN        MSFT        META        GOOG        TSLA  \
# Date
# 2016-07-12   37.410500   47.044460  116.903404   35.717094   14.976667
# 2016-07-13   37.131500   47.309711  115.763420   35.535690   14.835333
# 2016-07-14   37.060001   47.513058  116.268974   35.732460   14.768667
# 2016-07-15   36.771999   47.477695  115.842720   35.677933   14.693333
# 2016-07-18   36.803501   47.707565  118.330872   36.368351   15.083333
# ...                ...         ...         ...         ...         ...
# 2026-07-06  244.160004  386.739990  600.289978  364.899994  419.769989
# 2026-07-07  245.979996  388.839996  615.580017  363.619995  402.899994
# 2026-07-08  243.619995  383.339996  603.119995  358.709991  394.059998
# 2026-07-09  247.039993  384.359985  631.479980  356.239990  406.549988
# 2026-07-10  245.339996  385.100006  669.210022  355.029999  407.760010
#
#                   AAPL        NVDA
# Date
# 2016-07-12   22.177629    1.295907
# 2016-07-13   22.052420    1.295416
# 2016-07-14   22.489510    1.308670
# 2016-07-15   22.487228    1.293453
# 2016-07-18   22.726261    1.300079
# ...                ...         ...
# 2026-07-06  312.660004  195.550003
# 2026-07-07  310.660004  196.929993
# 2026-07-08  313.390015  204.119995
# 2026-07-09  316.220001  202.779999
# 2026-07-10  315.320007  210.960007
#
# [2513 rows x 7 columns]

# %%
cl_price.mean()
# Out:
# AMZN    131.190796
# MSFT    240.675393
# META    304.824463
# GOOG    115.808229
# TSLA    169.998348
# AAPL    127.179059
# NVDA     46.095825
# dtype: float64

# %%
cl_price.std()
# Out:
# AMZN     59.400895
# MSFT    138.877029
# META    184.311687
# GOOG     75.924791
# TSLA    138.585504
# AAPL     78.202770
# NVDA     61.433924
# dtype: float64

# %%
cl_price.median()
# Out:
# AMZN    127.739998
# MSFT    235.106827
# META    219.224838
# GOOG    100.323975
# TSLA    183.250000
# AAPL    131.494888
# NVDA     14.722050
# dtype: float64

# %%
cl_price.describe()
# Out:
#               AMZN         MSFT         META         GOOG         TSLA  \
# count  2513.000000  2513.000000  2513.000000  2513.000000  2513.000000
# mean    131.190796   240.675393   304.824463   115.808229   169.998348
# std      59.400895   138.877029   184.311687    75.924791   138.585504
# min      35.953499    46.938385    88.136032    35.535690    11.931333
# 25%      86.982498   102.951584   169.055405    56.540005    21.931999
# 50%     127.739998   235.106827   219.224838   100.323975   183.250000
# 75%     173.565506   367.372162   373.232452   144.567383   266.500000
# max     274.989990   538.658508   787.419189   398.799988   489.880005
#
#               AAPL         NVDA
# count  2513.000000  2513.000000
# mean    127.179059    46.095825
# std      78.202770    61.433924
# min      22.006893     1.293453
# 25%      45.902645     5.212819
# 50%     131.494888    14.722050
# 2026-07-10 -0.006881  0.001925  0.059749 -0.003397  0.002976 -0.002846
#
#                 NVDA
# Date
# 2016-07-12       NaN
# 2016-07-13 -0.000379
# 2016-07-14  0.010231
# 2016-07-15 -0.011628
# 2016-07-18  0.005123
# ...              ...
# 2026-07-06  0.003696
# 2026-07-07  0.007057
# 2026-07-08  0.036510
# 2026-07-09 -0.006565
# 2026-07-10  0.040339
#
# [2513 rows x 7 columns]

# %%
price_change_return = cl_price/cl_price.shift(1) - 1  #Calculate Price Change Return in Percentage
price_change_return
# Out:
#                 AMZN      MSFT      META      GOOG      TSLA      AAPL  \
# Date
# 2016-07-12       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-07-13 -0.007458  0.005638 -0.009752 -0.005079 -0.009437 -0.005646
# 2016-07-14 -0.001926  0.004298  0.004367  0.005537 -0.004494  0.019820
# 2016-07-15 -0.007771 -0.000744 -0.003666 -0.001526 -0.005101 -0.000101
# 2016-07-18  0.000857  0.004842  0.021479  0.019351  0.026543  0.010630
# ...              ...       ...       ...       ...       ...       ...
# 2026-07-06  0.006140 -0.009603  0.029834  0.024482  0.066895  0.013058
# 2026-07-07  0.007454  0.005430  0.025471 -0.003508 -0.040189 -0.006397
# 2026-07-08 -0.009594 -0.014145 -0.020241 -0.013503 -0.021941  0.008788
# 2026-07-09  0.014038  0.002661  0.047022 -0.006886  0.031696  0.009030
# 2026-07-10 -0.006881  0.001925  0.059749 -0.003397  0.002976 -0.002846
#
#                 NVDA
# Date
# 2016-07-12       NaN
# 2016-07-13 -0.000379
# 2016-07-14  0.010231
# 2016-07-15 -0.011628
# 2016-07-18  0.005123
# ...              ...
# 2026-07-06  0.003696
# 2026-07-07  0.007057
# 2026-07-08  0.036510
# 2026-07-09 -0.006565
# 2026-07-10  0.040339
#
# [2513 rows x 7 columns]

# %%
df = daily_return.rolling(window=10).mean()
df.dropna()
# Out:
#                 AMZN      MSFT      META      GOOG      TSLA      AAPL  \
# Date
# 2016-07-26 -0.001686  0.006622  0.002800  0.002464  0.002315 -0.000730
# 2016-07-27 -0.000794  0.005054  0.005524  0.003426  0.002815  0.006331
# 2016-07-28  0.001562  0.004659  0.006433  0.003430  0.004192  0.005699
# 2016-07-29  0.003163  0.005570  0.005952  0.006650  0.006515  0.005584
# 2016-08-01  0.004255  0.004909  0.004103  0.005247  0.001824  0.006287
# ...              ...       ...       ...       ...       ...       ...
# 2026-07-06  0.000169  0.002304  0.004554 -0.000375  0.005780  0.005223
# 2026-07-07  0.005661  0.006026  0.009417  0.004358  0.000622  0.004919
# 2026-07-08  0.004135  0.002815  0.007686  0.003782  0.004215  0.006710
# 2026-07-09  0.005470  0.005349  0.013194  0.003394  0.008978  0.008028
# 2026-07-10  0.007881  0.008997  0.021823  0.003880  0.009385  0.013861
#
#                 NVDA
# Date
# 2016-07-26  0.007115
# 2016-07-27  0.006146
# 2016-07-28  0.005337
# 2016-07-29  0.008138
# 2016-08-01  0.006977
# ...              ...
# 2026-07-06 -0.007276
# 2026-07-07 -0.005602
# 2026-07-08  0.002175
# 2026-07-09  0.002039
# 2026-07-10  0.007711
#
# [2503 rows x 7 columns]

# %%
daily_return.ewm(com=10, min_periods = 10).mean() #exponential moving averages
# Out:
#                 AMZN      MSFT      META      GOOG      TSLA      AAPL  \
# Date
# 2016-07-12       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-07-13       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-07-14       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-07-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2016-07-18       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2026-07-06  0.000939  0.000335  0.003808  0.002323  0.004811  0.005826
# 2026-07-07  0.001531  0.000798  0.005777  0.001793  0.000720  0.004715
# 2026-07-08  0.000520 -0.000560  0.003412  0.000403 -0.001340  0.005085
# 2026-07-09  0.001749 -0.000267  0.007377 -0.000260  0.001663  0.005444
# 2026-07-10  0.000964 -0.000068  0.012138 -0.000545  0.001783  0.004690
#
#                 NVDA
# Date
# 2016-07-12       NaN
# 2016-07-13       NaN
# 2016-07-14       NaN
# 2016-07-15       NaN
# 2016-07-18       NaN
# ...              ...
# 2026-07-06 -0.003080
# 2026-07-07 -0.002158
# 2026-07-08  0.001357
# 2026-07-09  0.000637
# 2026-07-10  0.004246
#
# [2513 rows x 7 columns]

# %%
cl_price.plot(title="Magnificient 7 Benchmark")
# Out:
# <Axes: title={'center': 'Magnificient 7 Benchmark'}, xlabel='Date'>

# %%
daily_return.plot(title="Daily Returns Seven's")
# Out:
# <Axes: title={'center': "Daily Returns Seven's"}, xlabel='Date'>

# %%
cumulative_return = (1+daily_return).cumprod() #cumprod, cumsum is a cumulative function

# %%
simulation = 1000 * cumulative_return

# %%
simulation.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
fig, ax = plt.subplots()
ax.set(title = "Mean Daily Return of Seven's", xlabel="Stocks", ylabel="Mean Return")

plt.bar(x=daily_return.columns, height=daily_return.mean()*100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File C:\ProgramData\anaconda3\Lib\contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# --> 883 with open(fname, encoding='utf-8') as f:
#     884     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn-dark'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[124], line 3
#       1 fig, ax = plt.subplots()
#       2 ax.set(title = "Mean Daily Return of Seven's", xlabel="Stocks", ylabel="Mean Return")
# ----> 3 plt.style.use("seaborn-dark")
#       4 plt.bar(x=daily_return.columns, height=daily_return.mean()*100)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\style\core.py:131, in use(style)
#     129         style = _rc_params_in_file(style)
#     130     except OSError as err:
# --> 131         raise OSError(
#     132             f"{style!r} is not a valid package style, path of style "
#     133             f"file, URL of style file, or library style name (library "
#     134             f"styles are listed in `style.available`)") from err
#     135 filtered = {}
#     136 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn-dark' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)

# %%
fig, ax = plt.subplots()
ax.set(title = "Mean Daily Return of Seven's", xlabel="Stocks", ylabel="Mean Return")
plt.style.use('ggplot')
plt.bar(x=daily_return.columns, height=daily_return.mean()*100)
# Out:
# <BarContainer object of 7 artists>
