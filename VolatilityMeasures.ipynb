# %%
import yfinance as yf
import numpy as np

# %%
tickers = ["AAPL", "MSFT", "GOOGL", "AMZN", "TSLA"]
ohlcv_data = {}

for ticker in tickers:
    stock = yf.download(ticker, period="1y", interval="1d")
    stock.dropna(how='any', inplace=True)
    ohlcv_data[ticker] = stock
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def calculate_volatility(DF):
    df = DF.copy()
    df["return"] = df["Close"].pct_change()
    vol = df["return"].std() * np.sqrt(252)
    return vol * 100

# %%
for ticker in ohlcv_data:
    vol = calculate_volatility(ohlcv_data[ticker])
    print(f"Volatility for {ticker}: {vol:.4f}")
# Out:
# Volatility for AAPL: 24.4434
# Volatility for MSFT: 27.4382
# Volatility for GOOGL: 30.5303
# Volatility for AMZN: 31.1677
# Volatility for TSLA: 44.6976
